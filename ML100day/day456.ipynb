# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/Social_Network_Ads.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
# User ID            400 non-null int64
# Gender             400 non-null object
# Age                400 non-null int64
# EstimatedSalary    400 non-null int64
# Purchased          400 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 15.7+ KB

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
g = sns.FacetGrid(df, col='Purchased')
g.map(plt.hist, 'Age', bins=10)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.Gender=le.fit_transform(df.Gender)
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19            19000          0
# 1    15810944       1   35            20000          0
# 2    15668575       0   26            43000          0
# 3    15603246       0   27            57000          0
# 4    15804002       1   19            76000          0
# 5    15728773       1   27            58000          0
# 6    15598044       0   27            84000          0
# 7    15694829       0   32           150000          1
# 8    15600575       1   25            33000          0
# 9    15727311       0   35            65000          0
# 10   15570769       0   26            80000          0
# 11   15606274       0   26            52000          0
# 12   15746139       1   20            86000          0
# 13   15704987       1   32            18000          0
# 14   15628972       1   18            82000          0
# 15   15697686       1   29            80000          0
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df.iloc[:,2:4] = sc.fit_transform(df.iloc[:,2:4])
df
# Out:
#       User ID  Gender       Age  EstimatedSalary  Purchased
# 0    15624510       1 -1.781797        -1.490046          0
# 1    15810944       1 -0.253587        -1.460681          0
# 2    15668575       0 -1.113206        -0.785290          0
# 3    15603246       0 -1.017692        -0.374182          0
# 4    15804002       1 -1.781797         0.183751          0
# 5    15728773       1 -1.017692        -0.344817          0
# 6    15598044       0 -1.017692         0.418669          0
# 7    15694829       0 -0.540127         2.356750          1
# 8    15600575       1 -1.208719        -1.078938          0
# 9    15727311       0 -0.253587        -0.139263          0
# 10   15570769       0 -1.113206         0.301210          0
# 11   15606274       0 -1.113206        -0.521006          0
# 12   15746139       1 -1.686284         0.477399          0
# 13   15704987       1 -0.540127        -1.519411          0
# 14   15628972       1 -1.877311         0.359940          0
# ...

# %%
from sklearn.model_selection import train_test_split
x_tr,x_te,y_tr,y_te=train_test_split(df.iloc[:,1:-1],df.iloc[:,-1],test_size=0.3,random_state = 0)
y_te
# Out:
# 132    0
# 309    0
# 341    0
# 196    0
# 246    0
# 60     0
# 155    0
# 261    1
# 141    0
# 214    0
# 37     0
# 134    0
# 113    0
# 348    0
# 12     0
# 59     0
# 293    0
# 140    0
# 206    1
# 199    0
# 176    0
# 268    1
# 124    0
# 344    1
# 175    0
# 313    1
# 78     0
# 15     0
# 286    0
# 102    0
#       ..
# 380    0
# 253    1
# 56     0
# 8      0
# 190    0
# 146    1
# 135    0
# 390    1
# 264    1
# 364    1
# 250    0
# 63     1
# 312    0
# 159    1
# 283    1
# 340    1
# 81     0
# 349    0
# 153    0
# 295    0
# 96     0
# 89     0
# 296    1
# 21     1
# 365    1
# 216    0
# 259    1
# 49     0
# 238    0
# 343    1
# Name: Purchased, Length: 120, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr=lr.fit(x_tr,y_tr)

# %%
lr.score(x_tr,y_tr)
# Out:
# 0.8357142857142857

# %%
lr.score(x_te,y_te)
# Out:
# 0.8916666666666667

# %%
lr.coef_
# Out:
# array([[0.14324002, 2.11887399, 1.04102122]])

# %% [markdown]
# # confusion_matrix相当约查全率和查准率的那个矩阵

# %%
y_pred=lr.predict(x_te)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_te, y_pred)
cm
# Out:
# array([[74,  5],
#        [ 8, 33]], dtype=int64)

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
plt.scatter(x_tr.iloc[:,1],x_tr.iloc[:,2],c=y_tr)
plt.show()
